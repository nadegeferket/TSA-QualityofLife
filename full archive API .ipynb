# %%
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
bearer_token='AAAAAAAAAAAAAAAAAAAAAHXvUQEAAAAAPQ%2FXl8vv2ZxuPlNEMn%2BbAvOg428%3DCNmiqFmvchzJIzzhLvyFBvL1mnOuwGjALg6uSbECpZIojXxUIM'

# %%
os.environ['TOKEN'] = 'AAAAAAAAAAAAAAAAAAAAAHXvUQEAAAAAPQ%2FXl8vv2ZxuPlNEMn%2BbAvOg428%3DCNmiqFmvchzJIzzhLvyFBvL1mnOuwGjALg6uSbECpZIojXxUIM'

# %%
def auth():
    return os.getenv('TOKEN')

# %%
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

# %%
def create_url(keyword, start_date, end_date, max_results = 10):
    
    search_url = "https://api.twitter.com/2/tweets/search/all" #Change to the endpoint you want to collect data from

    #change params based on the endpoint you are using. In the case of the full-archive search endpoint, 
    #the *query* parameter is the only parameter that is **required** to make a request. 
    #The query parameter is where you put the keyword(s) you want to search for.
    query_params = {'query': keyword,
                    'start_time': start_date,
                    'end_time': end_date,
                    'max_results': max_results,
                    'expansions': 'author_id,in_reply_to_user_id,geo.place_id',
                    'tweet.fields': 'id,text,author_id,in_reply_to_user_id,geo,conversation_id,created_at,lang,public_metrics,referenced_tweets,reply_settings,source',
                    'user.fields': 'id,name,username,created_at,description,public_metrics,verified',
                    'place.fields': 'full_name,id,country,country_code,geo,name,place_type',
                    'next_token': {}}
    return (search_url, query_params)

# %%
def connect_to_endpoint(url, headers, params, next_token = None):
    params['next_token'] = next_token   #params object received from create_url function
    response = requests.request("GET", url, headers = headers, params = params)
    print("Endpoint Response Code: " + str(response.status_code))
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

# %%
bearer_token = auth()
headers = create_headers(bearer_token)
keyword = "xbox lang:en"
start_time = "2021-03-01T00:00:00.000Z"
end_time = "2021-03-31T00:00:00.000Z"
max_results = 15

# %%
url = create_url(keyword, start_time,end_time, max_results)
json_response = connect_to_endpoint(url[0], headers, url[1])
# Out:
# Endpoint Response Code: 200

# %%
print(json.dumps(json_response, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "author_id": "21473901",
#             "conversation_id": "1376983819060928519",
#             "created_at": "2021-03-30T23:59:58.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047986186911750"
#             ],
#             "id": "1377047986186911750",
#             "in_reply_to_user_id": "234526497",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1376983819060928519",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@Chaosxsilencer Xbox Cash"
#         },
#         {
#             "author_id": "28189364",
#             "conversation_id": "1377047921624035328",
#             "created_at": "2021-03-30T23:59:43.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047921624035328"
#             ],
#             "id": "1377047921624035328",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 349
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1377047604899512320",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @RatalaikaGames: C14 Dating releases this week on #PS4,  #PS5, #Xbox &amp; #Switch!\n\nPlay as Melissa, an anthropology student on this otome\u2026"
#         },
#         {
#             "author_id": "1356995048081080320",
#             "conversation_id": "1376957152602988544",
#             "created_at": "2021-03-30T23:59:43.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047920634179586"
#             ],
#             "id": "1377047920634179586",
#             "in_reply_to_user_id": "915515915411783680",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1377046287292493828",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@foodiewithafro @NotYourDarling2 @Klassic_FyeSign @TMZ That was a giveaway for a xbox, she didn\u2019t actually get partnered with them until this year. \n\nhttps://t.co/5n1iky3bYT"
#         },
#         {
#             "author_id": "1087799995821162496",
#             "conversation_id": "1377046009918976000",
#             "created_at": "2021-03-30T23:59:35.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047889726349312"
#             ],
#             "id": "1377047889726349312",
#             "in_reply_to_user_id": "1292996837742436352",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1377047329459613700",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@SJRUTD @_mufcjay Man like Sam on xbox una"
#         },
#         {
#             "author_id": "809840101609963520",
#             "conversation_id": "1377047870033956864",
#             "created_at": "2021-03-30T23:59:31.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047870033956864"
#             ],
#             "id": "1377047870033956864",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 860
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1376946965297041409",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @agentbizzle: I really, really wish that PlayStation was as serious about preserving their legacy &amp; video game software history as Xbox\u2026"
#         },
#         {
#             "author_id": "1150942307971149825",
#             "conversation_id": "1377013572522422274",
#             "created_at": "2021-03-30T23:59:26.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047850224386049"
#             ],
#             "id": "1377047850224386049",
#             "in_reply_to_user_id": "468459371",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1377013572522422274",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@GameRiotArmy Xbox live games have never been quality"
#         },
#         {
#             "author_id": "1372681346363977728",
#             "conversation_id": "1377035919023251457",
#             "created_at": "2021-03-30T23:59:20.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047825649831936"
#             ],
#             "id": "1377047825649831936",
#             "in_reply_to_user_id": "1285236661392007169",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1377035919023251457",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@xbox_awesome @metroidfact hes taking something out of his foreskin"
#         },
#         {
#             "author_id": "427860188",
#             "conversation_id": "1377047817370406914",
#             "created_at": "2021-03-30T23:59:18.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047817370406914"
#             ],
#             "id": "1377047817370406914",
#             "in_reply_to_user_id": "24742040",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@Xbox @Microsoft kinda failing your community with your lack of inventory since launch. Can you just give everyone who has a valid xbox live account a pass for a series x. Thanks. Yours truly."
#         },
#         {
#             "author_id": "3241404782",
#             "conversation_id": "1377047815063543808",
#             "created_at": "2021-03-30T23:59:18.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047815063543808"
#             ],
#             "id": "1377047815063543808",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 349
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1377047604899512320",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "RT @RatalaikaGames: C14 Dating releases this week on #PS4,  #PS5, #Xbox &amp; #Switch!\n\nPlay as Melissa, an anthropology student on this otome\u2026"
#         },
#         {
#             "author_id": "729676104",
#             "conversation_id": "1376564814034563090",
#             "created_at": "2021-03-30T23:59:17.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047813452754945"
#             ],
#             "id": "1377047813452754945",
#             "in_reply_to_user_id": "4923119260",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1377042724445118464",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@Hamaad_Nazir @Xbox Haha No worries \ud83d\udc4c\ud83c\udffc"
#         },
#         {
#             "author_id": "1291232375532408832",
#             "conversation_id": "1376675565474770944",
#             "created_at": "2021-03-30T23:59:11.000Z",
#             "edit_history_tweet_ids": [
#                 "1377047786223403009"
#             ],
#             "id": "1377047786223403009",
#             "in_reply_to_user_id": "1286714483621212162",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 1,
#                 "retweet_count": 0
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1376997137251196933",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "@TruGiffers @Puertorock77_ @ODST_One_X Don't have to Xbox is the best place to play. No need for Single player story games with no action."
#         }
#     ],
#     "errors": [
#         {
#             "detail": "User has been suspended: [1286714483621212162].",
#             "parameter": "in_reply_to_user_id",
#             "resource_id": "1286714483621212162",
#             "resource_type": "user",
#             "title": "Forbidden",
#             "type": "https://api.twitter.com/2/problems/resource-not-found",
#             "value": "1286714483621212162"
#         }
#     ],
#     "includes": {
#         "users": [
#             {
#                 "created_at": "2009-02-21T09:32:43.000Z",
#                 "description": "Ravens, Xbox, and Cars",
#                 "id": "21473901",
#                 "name": "the King of Baltimore",
#                 "public_metrics": {
#                     "followers_count": 270,
#                     "following_count": 2836,
#                     "listed_count": 3,
#                     "tweet_count": 14318
#                 },
#                 "username": "biglouravens",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-01-05T21:48:22.000Z",
#                 "description": "I tweet about video games, movies, marvel, technology, pop culture & a little bit of everything else! I also reply a lot!  biz email chaos@moreyellow.com",
#                 "id": "234526497",
#                 "name": "Chaos",
#                 "public_metrics": {
#                     "followers_count": 446402,
#                     "following_count": 1725,
#                     "listed_count": 383,
#                     "tweet_count": 143104
#                 },
#                 "username": "Chaosxsilencer",
#                 "verified": true
#             },
#             {
#                 "created_at": "2009-04-01T20:38:02.000Z",
#                 "description": "\ud83c\udde7\ud83c\uddf7 \ud83c\uddf5\ud83c\uddea \n\ud83d\udcbb  @StudioKrakenRN | @sucodm | @despertarnerd\n\n#Branding #IndieDev #IndieGame #GameDev\n#ReleaseTheKraken \ud83d\udc19",
#                 "id": "28189364",
#                 "name": "Victor Olavo Roca",
#                 "public_metrics": {
#                     "followers_count": 784,
#                     "following_count": 1962,
#                     "listed_count": 7,
#                     "tweet_count": 22144
#                 },
#                 "username": "victorolavoroca",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-02-03T15:57:13.000Z",
#                 "description": "",
#                 "id": "1356995048081080320",
#                 "name": "~ max; \ud83d\udcab",
#                 "public_metrics": {
#                     "followers_count": 12,
#                     "following_count": 253,
#                     "listed_count": 0,
#                     "tweet_count": 330
#                 },
#                 "username": "justmaxweII",
#                 "verified": false
#             },
#             {
#                 "created_at": "2017-10-04T09:56:18.000Z",
#                 "description": "IG: Foodiewithafro",
#                 "id": "915515915411783680",
#                 "name": "Talicia",
#                 "public_metrics": {
#                     "followers_count": 3687,
#                     "following_count": 4419,
#                     "listed_count": 11,
#                     "tweet_count": 470
#                 },
#                 "username": "foodiewithafro",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-01-22T19:51:44.000Z",
#                 "description": "that/nigga",
#                 "id": "1087799995821162496",
#                 "name": "\ud83d\udca7",
#                 "public_metrics": {
#                     "followers_count": 1163,
#                     "following_count": 1298,
#                     "listed_count": 0,
#                     "tweet_count": 8145
#                 },
#                 "username": "harleyUTD",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-08-11T01:30:52.000Z",
#                 "description": "Ivan Toney x Marshall advocate",
#                 "id": "1292996837742436352",
#                 "name": "Sam \ud83c\udde9\ud83c\uddf0",
#                 "public_metrics": {
#                     "followers_count": 2042,
#                     "following_count": 684,
#                     "listed_count": 11,
#                     "tweet_count": 55231
#                 },
#                 "username": "SJRUTD",
#                 "verified": false
#             },
#             {
#                 "created_at": "2016-12-16T19:18:21.000Z",
#                 "description": "No Remedy - KILJ",
#                 "id": "809840101609963520",
#                 "name": "Lexi \u2606",
#                 "public_metrics": {
#                     "followers_count": 196,
#                     "following_count": 291,
#                     "listed_count": 1,
#                     "tweet_count": 10728
#                 },
#                 "username": "LexiCole117",
#                 "verified": false
#             },
#             {
#                 "created_at": "2019-07-16T01:36:44.000Z",
#                 "description": "I like Anime, Video Games, and Ramen!",
#                 "id": "1150942307971149825",
#                 "name": "Daniel San Bridges",
#                 "public_metrics": {
#                     "followers_count": 55,
#                     "following_count": 275,
#                     "listed_count": 0,
#                     "tweet_count": 1747
#                 },
#                 "username": "Only_Daniel0458",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-01-19T15:25:23.000Z",
#                 "description": "YouTuber https://t.co/Xwb0j1wepW\nEmail - gameriotbusiness@gmail.com",
#                 "id": "468459371",
#                 "name": "GameRiot",
#                 "public_metrics": {
#                     "followers_count": 56048,
#                     "following_count": 2020,
#                     "listed_count": 111,
#                     "tweet_count": 79240
#                 },
#                 "username": "GameRiotArmy",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-03-18T22:48:39.000Z",
#                 "description": "awesome australia facts\n\nfun facts about the deadly place\n\nnot for ankle biters (babies)",
#                 "id": "1372681346363977728",
#                 "name": "awesome australia facts",
#                 "public_metrics": {
#                     "followers_count": 1542,
#                     "following_count": 475,
#                     "listed_count": 16,
#                     "tweet_count": 2186
#                 },
#                 "username": "awesomeckf",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-07-20T15:34:42.000Z",
#                 "description": "awesome xbox facts (not for kids) banner by @MisterrMystic",
#                 "id": "1285236661392007169",
#                 "name": "awesome xbox facts",
#                 "public_metrics": {
#                     "followers_count": 31962,
#                     "following_count": 236,
#                     "listed_count": 69,
#                     "tweet_count": 7413
#                 },
#                 "username": "xbox_awesome",
#                 "verified": false
#             },
#             {
#                 "created_at": "2011-12-04T02:09:45.000Z",
#                 "description": "Business consultant and Point-of-Sales dealer from Lexington KY now in Tennessee.",
#                 "id": "427860188",
#                 "name": "Logan Gill",
#                 "public_metrics": {
#                     "followers_count": 38,
#                     "following_count": 201,
#                     "listed_count": 0,
#                     "tweet_count": 873
#                 },
#                 "username": "Gillishere",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-03-16T18:30:52.000Z",
#                 "description": "Be on in 5",
#                 "id": "24742040",
#                 "name": "Xbox",
#                 "public_metrics": {
#                     "followers_count": 20069384,
#                     "following_count": 15987,
#                     "listed_count": 21274,
#                     "tweet_count": 295323
#                 },
#                 "username": "Xbox",
#                 "verified": true
#             },
#             {
#                 "created_at": "2015-06-10T13:59:46.000Z",
#                 "description": "#1 Xbox Community https://t.co/RfBvjqKSeC https://t.co/uLYHWFRogf #Ambassador #Press #Influencer #Reviews #PR #Partner #Xbox #XboxOne #XboxSeriesX",
#                 "id": "3241404782",
#                 "name": "Xbox_Alive",
#                 "public_metrics": {
#                     "followers_count": 5823,
#                     "following_count": 2147,
#                     "listed_count": 24,
#                     "tweet_count": 4556
#                 },
#                 "username": "SmallywoodXA",
#                 "verified": false
#             },
#             {
#                 "created_at": "2012-08-01T01:27:46.000Z",
#                 "description": "29 \ud83c\udf89 | Gamer \ud83c\udfae | Achievement Hunter \ud83c\udfc6 | 600K+ Gamerscore \ud83d\udc8e | Xbox: Kripliss \ud83d\udc9a | PSN:Kripliss10 \ud83d\udc99 | PatsNation \ud83c\udfc8",
#                 "id": "729676104",
#                 "name": "Kripliss \ud83c\udfc6",
#                 "public_metrics": {
#                     "followers_count": 808,
#                     "following_count": 379,
#                     "listed_count": 4,
#                     "tweet_count": 6683
#                 },
#                 "username": "Kripliss_Gaming",
#                 "verified": false
#             },
#             {
#                 "created_at": "2016-02-17T08:41:37.000Z",
#                 "description": "yup that\u2019s me",
#                 "id": "4923119260",
#                 "name": "Hamad",
#                 "public_metrics": {
#                     "followers_count": 20,
#                     "following_count": 626,
#                     "listed_count": 0,
#                     "tweet_count": 2299
#                 },
#                 "username": "Hamaad_Nazir",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-08-06T04:39:38.000Z",
#                 "description": "Welcome to the Next Generation.",
#                 "id": "1291232375532408832",
#                 "name": "ManiacManny96",
#                 "public_metrics": {
#                     "followers_count": 0,
#                     "following_count": 20,
#                     "listed_count": 0,
#                     "tweet_count": 395
#                 },
#                 "username": "Gamer77Maniac",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1377047986186911750",
#         "next_token": "b26v89c19zqg8o3fosqtycrburi6z6yf9hremiwdnb531",
#         "oldest_id": "1377047786223403009",
#         "result_count": 11
#     }
# }

# %%
json_response['data'][0]['created_at']
# Out:
# '2021-03-30T23:59:58.000Z'

# %%
json_response['meta']['result_count']
# Out:
# 11

# %%
with open('data.json', 'w') as f:
    json.dump(json_response, f)
