# %%
# !pip install git+https://github.com/vsa-datascience/vlaams-twitter-sentiment-model.git
# Out:
# Collecting git+https://github.com/vsa-datascience/vlaams-twitter-sentiment-model.git
#   Cloning https://github.com/vsa-datascience/vlaams-twitter-sentiment-model.git to c:\users\nadeg\appdata\local\temp\pip-req-build-yb7qq6ts
#   Resolved https://github.com/vsa-datascience/vlaams-twitter-sentiment-model.git to commit 4d4dec73595463301b731b278d9a27d5c2ef2bb4
# Requirement already satisfied: scikit-learn in c:\users\nadeg\anaconda3\lib\site-packages (from twitter-sentiment-classifier==0.1.1) (0.24.2)
# Requirement already satisfied: torch in c:\users\nadeg\anaconda3\lib\site-packages (from twitter-sentiment-classifier==0.1.1) (1.13.1)
# Requirement already satisfied: transformers in c:\users\nadeg\anaconda3\lib\site-packages (from twitter-sentiment-classifier==0.1.1) (4.25.1)
# Requirement already satisfied: tqdm in c:\users\nadeg\anaconda3\lib\site-packages (from twitter-sentiment-classifier==0.1.1) (4.62.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\nadeg\anaconda3\lib\site-packages (from scikit-learn->twitter-sentiment-classifier==0.1.1) (1.7.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\nadeg\anaconda3\lib\site-packages (from scikit-learn->twitter-sentiment-classifier==0.1.1) (1.22.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\nadeg\anaconda3\lib\site-packages (from scikit-learn->twitter-sentiment-classifier==0.1.1) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nadeg\anaconda3\lib\site-packages (from scikit-learn->twitter-sentiment-classifier==0.1.1) (2.2.0)
# Requirement already satisfied: typing-extensions in c:\users\nadeg\anaconda3\lib\site-packages (from torch->twitter-sentiment-classifier==0.1.1) (3.7.4.3)
# Requirement already satisfied: colorama in c:\users\nadeg\anaconda3\lib\site-packages (from tqdm->twitter-sentiment-classifier==0.1.1) (0.4.4)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\nadeg\anaconda3\lib\site-packages (from transformers->twitter-sentiment-classifier==0.1.1) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\nadeg\anaconda3\lib\site-packages (from transformers->twitter-sentiment-classifier==0.1.1) (0.11.1)
# Requirement already satisfied: filelock in c:\users\nadeg\anaconda3\lib\site-packages (from transformers->twitter-sentiment-classifier==0.1.1) (3.3.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\nadeg\anaconda3\lib\site-packages (from transformers->twitter-sentiment-classifier==0.1.1) (2021.8.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\nadeg\anaconda3\lib\site-packages (from transformers->twitter-sentiment-classifier==0.1.1) (21.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\nadeg\anaconda3\lib\site-packages (from transformers->twitter-sentiment-classifier==0.1.1) (0.13.2)
# Requirement already satisfied: requests in c:\users\nadeg\anaconda3\lib\site-packages (from transformers->twitter-sentiment-classifier==0.1.1) (2.28.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\nadeg\anaconda3\lib\site-packages (from packaging>=20.0->transformers->twitter-sentiment-classifier==0.1.1) (3.0.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\nadeg\anaconda3\lib\site-packages (from requests->transformers->twitter-sentiment-classifier==0.1.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nadeg\anaconda3\lib\site-packages (from requests->transformers->twitter-sentiment-classifier==0.1.1) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\nadeg\anaconda3\lib\site-packages (from requests->transformers->twitter-sentiment-classifier==0.1.1) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nadeg\anaconda3\lib\site-packages (from requests->transformers->twitter-sentiment-classifier==0.1.1) (2021.10.8)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nadeg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nadeg\anaconda3\lib\site-packages)
#   Running command git clone -q https://github.com/vsa-datascience/vlaams-twitter-sentiment-model.git 'C:\Users\nadeg\AppData\Local\Temp\pip-req-build-yb7qq6ts'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nadeg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nadeg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nadeg\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\nadeg\anaconda3\lib\site-packages)

# %%
from twitter_sentiment_classifier import batch_predict

import pandas
colnames = [ c for c in "abcdefghujklmnopqrst"]
data = pandas.read_csv('Downloads\\tweet_output_path2.csv', names=colnames) #geef eigen doc in
texts = data.o.tolist()[1:]
for i in range(0,len(texts)):
    #preprocessing stap: vervangen van einde lijn naar spatie
    texts[i] = texts[i].replace("\n"," ")
    
batch_predict(texts)
# Out:
# Predicting...: 100%|██████████| 3/3 [00:13<00:00,  4.57s/it]
# ['NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEUTRAL',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEGATIVE',
#  'NEGATIVE',
#  'POSITIVE',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEGATIVE',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEUTRAL',
#  'NEGATIVE']
